# %%
import pandas as pd

# %%
csv1 = pd.read_csv("C:\\Users\\Ranjan Kumar\\Desktop\\All Excel Practice Files\\Books.csv")
csv1
# Out:
#      Book_ID                                         Title  \
# 0          1               Configurable modular throughput
# 1          2         Persevering reciprocal knowledge user
# 2          3               Streamlined coherent initiative
# 3          4                   Customizable 24hour product
# 4          5               Adaptive 5thgeneration encoding
# ..       ...                                           ...
# 495      496                Decentralized radical forecast
# 496      497             Function-based local installation
# 497      498                       Secured 24/7 neural-net
# 498      499  Compatible transitional budgetary management
# 499      500     Vision-oriented zero tolerance initiative
#
#                   Author            Genre  Published_Year  Price  Stock
# 0           Joseph Crane        Biography            1949  21.34    100
# 1            Mario Moore          Fantasy            1971  35.80     19
# ...

# %%
csv1.replace(to_replace="Joseph Crane" , value= "robin")
# Out:
#      Book_ID                                         Title  \
# 0          1               Configurable modular throughput
# 1          2         Persevering reciprocal knowledge user
# 2          3               Streamlined coherent initiative
# 3          4                   Customizable 24hour product
# 4          5               Adaptive 5thgeneration encoding
# ..       ...                                           ...
# 495      496                Decentralized radical forecast
# 496      497             Function-based local installation
# 497      498                       Secured 24/7 neural-net
# 498      499  Compatible transitional budgetary management
# 499      500     Vision-oriented zero tolerance initiative
#
#                   Author            Genre  Published_Year  Price  Stock
# 0                  robin        Biography            1949  21.34    100
# 1            Mario Moore          Fantasy            1971  35.80     19
# ...

# %%
csv1.replace({"Title": '[Configurable mudular throughout]'}, "Robin", regex= True)
# Out:
#      Book_ID                                              Title  \
# 0          1  RobinRobinRobinRobinRobinRobinRobinRobinRobinR...
# 1          2  PRobinRobinsRobinvRobinRobinRobinRobinRobinRob...
# 2          3  SRobinRobinRobinRobinRobinRobinRobinRobinRobin...
# 3          4  RobinRobinsRobinRobinRobinRobinzRobinRobinRobi...
# 4          5  ARobinRobinpRobinRobinvRobinRobin5RobinRobinRo...
# ..       ...                                                ...
# 495      496  DRobincRobinRobinRobinRobinRobinRobinRobinzRob...
# 496      497  FRobinRobincRobinRobinRobinRobin-RobinRobinsRo...
# 497      498  SRobincRobinRobinRobinRobinRobin24/7RobinRobin...
# 498      499  RobinRobinRobinpRobinRobinRobinRobinRobinRobin...
# 499      500  VRobinsRobinRobinRobin-RobinRobinRobinRobinRob...
#
#                   Author            Genre  Published_Year  Price  Stock
# 0           Joseph Crane        Biography            1949  21.34    100
# ...

# %%
csv1.replace(1,method= 'bfill')
# Out:
# C:\Users\Ranjan Kumar\AppData\Local\Temp\ipykernel_24708\2583328558.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   csv1.replace(1,method= 'bfill')
#      Book_ID                                         Title  \
# 0          2               Configurable modular throughput
# 1          2         Persevering reciprocal knowledge user
# 2          3               Streamlined coherent initiative
# 3          4                   Customizable 24hour product
# 4          5               Adaptive 5thgeneration encoding
# ..       ...                                           ...
# 495      496                Decentralized radical forecast
# 496      497             Function-based local installation
# 497      498                       Secured 24/7 neural-net
# 498      499  Compatible transitional budgetary management
# 499      500     Vision-oriented zero tolerance initiative
#
# ...
