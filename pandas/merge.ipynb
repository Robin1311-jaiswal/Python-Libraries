# %%
import pandas as pd

# %%
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]})
var2= pd.DataFrame({"A":[1,2,3,4], "C":[21,21,22,23]})

pd.merge(var1,var2, on = "A")
# Out:
#    A   B   C
# 0  1  11  21
# 1  2  12  21
# 2  3  13  22
# 3  4  14  23

# %%
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]})
var2= pd.DataFrame({"A":[1,2,3,5], "C":[21,21,22,23]})

pd.merge(var1,var2, on = "A")
# Out:
#    A   B   C
# 0  1  11  21
# 1  2  12  21
# 2  3  13  22

# %%
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]})
var2= pd.DataFrame({"A":[1,2,3,5], "C":[21,21,22,23]})

pd.merge(var1,var2, how="left")
# Out:
#    A   B     C
# 0  1  11  21.0
# 1  2  12  21.0
# 2  3  13  22.0
# 3  4  14   NaN

# %%
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]})
var2= pd.DataFrame({"A":[1,2,3,5], "C":[21,21,22,23]})

pd.merge(var1,var2, "right")
# Out:
#    A     B   C
# 0  1  11.0  21
# 1  2  12.0  21
# 2  3  13.0  22
# 3  5   NaN  23

# %%
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]})
var2= pd.DataFrame({"A":[1,2,3,5], "C":[21,21,22,23]})

pd.merge(var1,var2, left_index=True, right_index=True)
# Out:
#    A_x   B  A_y   C
# 0    1  11    1  21
# 1    2  12    2  21
# 2    3  13    3  22
# 3    4  14    5  23

# %%
var1= pd.DataFrame({"A":[1,2,3,4],"B":[11,12,13,14]})
var2= pd.DataFrame({"A":[1,2,3,5], "C":[21,21,22,23]})

pd.merge(var1,var2, left_index=True, right_index=True, suffixes=("name", "python"))
# Out:
#    Aname   B  Apython   C
# 0      1  11        1  21
# 1      2  12        2  21
# 2      3  13        3  22
# 3      4  14        5  23
