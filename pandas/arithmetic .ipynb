# %%
import pandas as pd

# %%
var = pd.DataFrame({"A":[1,2,3,4],"B":[5,6,7,8]})
var
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
var["C"]= var["A"] + var["B"]
var
# Out:
#    A  B   C
# 0  1  5   6
# 1  2  6   8
# 2  3  7  10
# 3  4  8  12

# %%
var["python"] = var["A"] <=3
var
# Out:
#    A  B   C  python
# 0  1  5   6    True
# 1  2  6   8    True
# 2  3  7  10    True
# 3  4  8  12   False
