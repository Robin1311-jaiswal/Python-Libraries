# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[3,2,4,5,4]

plt.step(x,y,marker="o", ms=10,mfc="g", label="python")
plt.title("Python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid()
