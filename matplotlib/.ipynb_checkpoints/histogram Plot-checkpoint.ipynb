# %%
import matplotlib.pyplot as plt
import numpy as np 
import random

x=np.random.randint(10,60,(50))
print(x)
# Out:
# [42 34 37 36 18 59 41 27 51 39 30 56 13 20 59 45 22 29 30 29 34 50 28 32
#  13 38 39 44 13 20 51 33 28 16 56 26 51 31 50 25 25 55 56 33 31 53 54 44
#  54 37]

# %%
no = [42, 34, 37, 36, 18, 59, 41, 27, 51, 39, 30, 56, 13, 20, 59, 45, 22, 29, 30, 29, 34, 50, 28, 32,
 13, 38, 39, 44, 13, 20, 51, 33, 28, 16, 56, 26, 51, 31, 50, 25, 25, 55, 56, 33, 31, 53, 54, 44,
 54, 37]

l = [10,20,30,40,50,60]
plt.hist(no, color="r",bins=l, edgecolor= "b")
plt.title("jaiswal")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no = [42, 34, 37, 36, 18, 59, 41, 27, 51, 39, 30, 56, 13, 20, 59, 45, 22, 29, 30, 29, 34, 50, 28, 32,
 13, 38, 39, 44, 13, 20, 51, 33, 28, 16, 56, 26, 51, 31, 50, 25, 25, 55, 56, 33, 31, 53, 54, 44,
 54, 37]

l = [10,20,30,40,50,60]
plt.hist(no, color="r", edgecolor= "b")
plt.title("jaiswal")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no = [42, 34, 37, 36, 18, 59, 41, 27, 51, 39, 30, 56, 13, 20, 59, 45, 22, 29, 30, 29, 34, 50, 28, 32,
 13, 38, 39, 44, 13, 20, 51, 33, 28, 16, 56, 26, 51, 31, 50, 25, 25, 55, 56, 33, 31, 53, 54, 44,
 54, 37]

l = [10,20,30,40,50,60]
plt.hist(no, "auto",(0,70), edgecolor= "b")
plt.title("jaiswal")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()
# Out:
# C:\Users\Ranjan Kumar\AppData\Local\Temp\ipykernel_19472\3464520213.py:6: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(no, "auto",(0,70), edgecolor= "b")

# %%
no = [42, 34, 37, 36, 18, 59, 41, 27, 51, 39, 30, 56, 13, 20, 59, 45, 22, 29, 30, 29, 34, 50, 28, 32,
 13, 38, 39, 44, 13, 20, 51, 33, 28, 16, 56, 26, 51, 31, 50, 25, 25, 55, 56, 33, 31, 53, 54, 44,
 54, 37]

l = [10,20,30,40,50,60]
plt.hist(no, color="r", edgecolor= "b", cumulative=-1)
plt.title("jaiswal")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no = [42, 34, 37, 36, 18, 59, 41, 27, 51, 39, 30, 56, 13, 20, 59, 45, 22, 29, 30, 29, 34, 50, 28, 32,
 13, 38, 39, 44, 13, 20, 51, 33, 28, 16, 56, 26, 51, 31, 50, 25, 25, 55, 56, 33, 31, 53, 54, 44,
 54, 37]

l = [10,20,30,40,50,60]
plt.hist(no, color="r", edgecolor= "b", bottom=10, align = "mid", rwidth= 0.8, label="python")
plt.title("jaiswal")
plt.xlabel("python")
plt.axvline(40, color="b", label="line")
plt.legend()
plt.ylabel("No.")
plt.show()

# %%
no = [42, 34, 37, 36, 18, 59, 41, 27, 51, 39, 30, 56, 13, 20, 59, 45, 22, 29, 30, 29, 34, 50, 28, 32,
 13, 38, 39, 44, 13, 20, 51, 33, 28, 16, 56, 26, 51, 31, 50, 25, 25, 55, 56, 33, 31, 53, 54, 44,
 54, 37]

l = [10,20,30,40,50,60]
plt.hist(no, color="r", edgecolor= "b", histtype="stepfilled")  #or step
plt.title("jaiswal")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no = [42, 34, 37, 36, 18, 59, 41, 27, 51, 39, 30, 56, 13, 20, 59, 45, 22, 29, 30, 29, 34, 50, 28, 32,
 13, 38, 39, 44, 13, 20, 51, 33, 28, 16, 56, 26, 51, 31, 50, 25, 25, 55, 56, 33, 31, 53, 54, 44,
 54, 37]

l = [10,20,30,40,50,60]
plt.hist(no, color="r", edgecolor= "b", histtype="step")  #or step bar barstep
plt.title("jaiswal")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no = [42, 34, 37, 36, 18, 59, 41, 27, 51, 39, 30, 56, 13, 20, 59, 45, 22, 29, 30, 29, 34, 50, 28, 32,
 13, 38, 39, 44, 13, 20, 51, 33, 28, 16, 56, 26, 51, 31, 50, 25, 25, 55, 56, 33, 31, 53, 54, 44,
 54, 37]

l = [10,20,30,40,50,60]
plt.hist(no, color="r", edgecolor= "b", orientation= "horizontal")  #or vertical
plt.title("jaiswal")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()
