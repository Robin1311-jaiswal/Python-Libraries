# %%
import numpy as np

# %%
var = np.array([1,2,3,4])
co =var.copy()
var[1]=34

print("var:" , var)
print("copy:", co)
# Out:
# var: [ 1 34  3  4]
# copy: [1 2 3 4]

# %%
var=np.array([4,5,6,7])
vi = var.view()
var[3]=43
print("var:", var)
print("view:", vi)
# Out:
# var: [ 4  5  6 43]
# view: [ 4  5  6 43]
