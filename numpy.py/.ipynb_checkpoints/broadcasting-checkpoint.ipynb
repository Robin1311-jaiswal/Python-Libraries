# %%
import numpy as np

# %%
var = np.array([2,3,4,5])
print(var.shape)
print(var)
print()
var2 = np.array([[1],[2],[3]])
print(var2.shape)
print(var2)
print()
print(np.add(var, var2))
# Out:
# (4,)
# [2 3 4 5]
#
# (3, 1)
# [[1]
#  [2]
#  [3]]
#
# [[3 4 5 6]
#  [4 5 6 7]
#  [5 6 7 8]]
