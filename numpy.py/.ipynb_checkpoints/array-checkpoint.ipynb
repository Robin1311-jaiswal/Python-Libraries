# %%
import  numpy as np 
x=[1,2,3,4]

y= np.array([1,2,3,4,5])
print(y)
print(type(y))
print(y.ndim)
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>
# 1

# %%
l=[]

for i in range (1,5):
    int_l = int(input("enter:"))
    l.append(int_l)
print(np.array(l))
# Out:
# enter: 12
# enter: 13
# enter: 14
# enter: 15
# [12 13 14 15]

# %%
ar2 = np.array([[1,2,3,4],[5,6,7,8]])
print(ar2)
print(ar2.ndim)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]
# 2

# %%
ar3 = np.array([[[1,2,3,4],[5,6,7,8],[6,8,9,0]]])
print(ar3)
print(ar3.ndim)
# Out:
# [[[1 2 3 4]
#   [5 6 7 8]
#   [6 8 9 0]]]
# 3

# %%
arn = np.array([1,2,3,4], ndmin =10)
print(arn)
print(arn.ndim)
# Out:
# [[[[[[[[[[1 2 3 4]]]]]]]]]]
# 10
