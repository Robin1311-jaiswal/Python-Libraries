# %% [markdown]
# #arithmertic operation

# %%
import numpy as np

# %%
var = np.array([1,2,3,4])
varadd= var + 3
print(varadd)
# Out:
# [4 5 6 7]

# %%
var = np.array([1,2,3,4])
var2= np.array([5,6,7,8])
print(var+var2)
# Out:
# [ 6  8 10 12]

# %%
var = np.array([4,5,6,6])
print(var-4)
# Out:
# [0 1 2 2]

# %%
var = np.array([3,4,5,6])
varadd = var*7
print(varadd)
# Out:
# [21 28 35 42]

# %%
var = np.array([2,4,5,6])
varadd = var/6
print(varadd)
# Out:
# [0.33333333 0.66666667 0.83333333 1.        ]
