# %%
import numpy as np

# %%
var = np.array([1,2,3])
print("data type :" , var.dtype)
# Out:
# data type : int64

# %%
var = np.array([1.2, 3.4, 4.2])
print("data type:" , var.dtype)
# Out:
# data type: float64

# %%
var = np.array(["robin"])
print("data type:", var.dtype)
# Out:
# data type: <U5

# %%
x= np.array([1,2,3,4])

print("data type:" ,x.dtype) 
print(x)
# Out:
# data type: int64
# [1 2 3 4]

# %%
x= np.array([1,2,3,4])

print("data type:" ,x.dtype) 
print(x)
# Out:
# data type: int64
# [1 2 3 4]

# %%
x2= np.array([1,2,3,4])
new = np.float32(x2)
print("data type:" ,x2.dtype)
print("data type:", new.dtype)
print(x2)
print(new)
# Out:
# data type: int64
# data type: float32
# [1 2 3 4]
# [1. 2. 3. 4.]

# %%
x3= np.array([1,2,3,4])

new_1 = x3.astype(float)
print(x3)
print(new_1)
# Out:
# [1 2 3 4]
# [1. 2. 3. 4.]
