# %%
import numpy as np

# %%
ar= np.array([1,2,3,4,6,7,8])
x= np.searchsorted(ar, 5)
print(x)
# Out:
# 4

# %%
ar= np.array([1,2,3,4,4,6,7,8,9])
x= np.searchsorted(ar, 5, side="right")
print(x)
# Out:
# 5

# %%
ar= np.array([1,2,3,4,4,6,7,8,9])
x= np.searchsorted(ar, [5,6,7,8] ,side="right")
print(x)
# Out:
# [5 6 7 8]

# %%
ar= np.array([1,2,3,4,4,6,7,8,9])
x= np.searchsorted(ar, [5,6,7,8] ,side="left")
print(x)
# Out:
# [5 5 6 7]

# %%
ar= np.array([1,2,3,4,6,7,8])
x= np.searchsorted(ar, 5)
print(x)
