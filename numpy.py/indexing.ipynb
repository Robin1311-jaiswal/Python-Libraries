# %%
import numpy as np

# %%
var= np.array([2,3,3,4])
print(var.ndim)
print(var[2])
print(var[-3])
# Out:
# 1
# 3
# 3

# %%
var= np.array([[1,2,3],[3,4,5]])
print(var.shape)
print(var.ndim)
print(var[0,1])
# Out:
# (2, 3)
# 2
# 2

# %%
var= np.array([[[1,2,3],[3,4,5]]])
print(var.shape)
print(var[0,1,2])
# Out:
# (1, 2, 3)
# 5
