# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset= pd.read_csv("C:\\Users\\Ranjan Kumar\\Downloads\\titanic.csv")

# %%
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
dataset["Age"].var()
# Out:
# 211.0191247463081

# %%
dataset["Age"].std()
# Out:
# 14.526497332334044

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.histplot(x="Age", data=dataset)
plt.show()

# %%
min_r= dataset["Age"].min()
max_r= dataset["Age"].max()

# %%
min_r, max_r
# Out:
# (0.42, 80.0)

# %%
range = max_r - min_r
range
# Out:
# 79.58

# %%
sec_a = np.array([75,65,73,58,72,76])
sec_b= np.array([90,47,43,96,93,51])
no= np.array([1,2,3,4,5,6])

mean= np.mean(sec_b)
mean
# Out:
# np.float64(70.0)

# %%
plt.figure(figsize=(10,3))
plt.scatter(sec_a,no,label="sec A")
plt.scatter(sec_b, no,color="red", label="Sec B")
plt.plot([70, 70, 70,70,70,70], no, c="b", label= "Mean")
plt.legend()
plt.show()

# %%
mad_a= np.sum(np.abs(sec_a-mean))/len(sec_a)
mad_b= np.sum(np.abs(sec_b-mean))/len(sec_b)

# %%
mad_a, mad_b
# Out:
# (np.float64(5.5), np.float64(23.0))
