# %%
import numpy as np
import pandas as pd

# %%
ar= np.array([3,2,4,5,6,4,6,6,8,4])

# %%
np.sum(ar)/len(ar)
# Out:
# np.float64(4.8)

# %%
np.sort(ar)
# Out:
# array([2, 3, 4, 4, 4, 5, 6, 6, 6, 8])

# %%
np.mean(ar)
# Out:
# np.float64(4.8)
