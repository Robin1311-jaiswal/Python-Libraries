# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pop_data= [np.random.randint(10,100) for i in range(10000)]
pop_table= pd.DataFrame({"Pop_data": pop_data})

# %%
plt.figure(figsize=(4,3))
sns.kdeplot(x="Pop_data", data=pop_table)
plt.show()

# %%
sample_mean=[]
for no_sample in range (50):
    sample_data =[]
    for data in range(500):
        sample_data.append(np.random.choice(pop_data))
        sample_mean.append(np.mean(sample_mean))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
sample_M= pd.DataFrame({"Sample_Mean": sample_mean})

# %%
plt.figure(figsize=(3,2))
sns.kdeplot(x="Sample_Mean", data= sample_M)
plt.show()
# Out:
# C:\Users\Ranjan Kumar\AppData\Local\Temp\ipykernel_9892\783858401.py:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x="Sample_Mean", data= sample_M)
